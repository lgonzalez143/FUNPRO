# %% [markdown]
# <a href="https://colab.research.google.com/github/lgonzalez143/FUNPRO/blob/main/Clase_11_Ejercicio_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def contador():
  notas=[]
  cantidad=int(input("cuantas notas componen el corte: "))
  for i in range(cantidad):
    nota=float(input(f"dijite sus notas:{i+1} "))
    notas.append(nota)
    print(notas)
  c=0
  for a in notas:
    if a>=3:
      c+=1
      print(f"van {c} notas")
  print(f"{c} notas fueron mayores o iguales a 3")
  return cantidad,notas

def promedio(notas,cantidad):
  total=sum(notas)
  promedio=total/cantidad
  print(f"su promedio es: {promedio}")

a,b=contador()
promedio(b,a)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
