# %% [markdown]
# <a href="https://colab.research.google.com/github/lgonzalez143/FUNPRO/blob/main/QUEST_FOUR_GP4_ARKANOIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GOOD PROGRAMMER QUEST FOUR GP4(5000k)
# Construir tu propia versión de arkanoid en app inventor
#
# link:
# https://drive.google.com/file/d/1fxh3txrD44zBVHHIjMRoYNk-blM9FaWv/view?usp=sharing
#
# https://ai2.appinventor.mit.edu/?locale=es_ES#4985277150986240

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
