# %% [markdown]
# <a href="https://colab.research.google.com/github/lgonzalez143/FUNPRO/blob/main/PROGRAMACION_EJERCICIO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
uno=0
i=1
cifras=int(input("ingresar la cantidad de cifras a analizar:"))
for i in range(1,cifras+1):
  num=int(input(f"ingrese el número {i}:"))
  if num==1:
    uno=uno+1
print(f"hay {uno} en {cifras} cifras")
# Out:
# ingresar la cantidad de cifras a analizar:4
# ingrese el número 1:1
# ingrese el número 2:11
# ingrese el número 3:10
# ingrese el número 4:6
# hay 1 en 4 cifras

# %% [markdown]
# ![image.png](data:image/png;base64,...)
