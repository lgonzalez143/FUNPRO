# %% [markdown]
# <a href="https://colab.research.google.com/github/lgonzalez143/FUNPRO/blob/main/Estructuras_de_relacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##IF-ELIF-ELSE
#
# Una de las formas para representar un switch
# 1. Hay una o varias variables a evaluar
# 2. Hay tantas condiciones como
# "paticas"+1
# 3. La ultima evaluacion es
# ninguna de las anteriores (else)
# 4. La primera patica siemrpe recibe el "if"
# 5. El resto de paticas
# recibe "elif"
# Sintaxis
#
# ````
# if condicion1:
#  expresion 1
# elif condicion2:
#  expresion 2
# elif condicion3:
#  expresion 3

# %%
1 #Pasa o no la materia, dependiendo de promedio>3 y asistencia >80%
2 nota=float(input("Ingrese su promedio"))
3 asistencia=int(input("Ingrese la cantidad de horas asistidas"))
4 horas_totales=int(input("Ingrese la cantidad de horas totales de la clase"))
5 if nota>=3 and asistencia>horas_totales*.8:
6   print(f"El estudiante pasó la materia con {nota} y asistió mas del 80% de las clases.")
7 elif nota<3 and asistencia>horas_totales*.8:
8    print(f"El estudiante pierde la materia con {nota} pero asistió a mas el 80% de las clases")
9 elif nota>=3 and asistencia<horas_totales*.8
10   print(f"El estudiante pasó la materia con {nota} pero pierde debido a inasistencias")
11 else:
12   print(f"El estudiante perdió la materia con {nota} y no asistió a las clases suficientes")
# Out:
#   File "/tmp/ipython-input-1016122241.py", line 2
#     2 nota=float(input("Ingrese su promedio"))
#       ^
# SyntaxError: invalid syntax

# %%
1 #Programa que identifique si la letra ingresada es una vocal mayuscula, minuscula
letra= input("Ingrese una letra: ")
match letra:
  case "a":print(f"{letra} es una vocal minúscula")
  case "e":print(f"{letra} es una vocal minúscula")
  case "i":print(f"{letra} es una vocal minúscula")
  case "o":print(f"{letra} es una vocal minúscula")
  case "u":print(f"{letra} es una vocal minúscula")
  case "A":print(f"{letra} es una vocal MAYÚSCULA")
  case "E":print(f"{letra} es una vocal MAYÚSCULA")
  case "I":print(f"{letra} es una vocal MAYÚSCULA")
  case "O":print(f"{letra} es una vocal MAYÚSCULA")
  case "U":print(f"{letra} es una vocal MAYÚSCULA")
  case_:print(f"{letra} no es una vocal")
# Out:
#   File "/tmp/ipython-input-3351508536.py", line 14
#     case_:print(f"{letra} no es una vocal")
#     ^
# SyntaxError: invalid syntax

# %%
if letra=="a" or letra=="e" or letra=="i" or letra=="o" or letra=="u":
  print (f"{letra} es una vocal minuscula")
elif letra=="A" or letra=="E" or letra=="I" or letra=="O" or letra=="U":
  print(f"{letra} es una vocal MAYÚSCULA")
else:
  print(f"{letra}no es una vocal")
# Out:
# A es una vocal MAYÚSCULA

# %%
#Programa de sistema de riego
humedad_suelo=float(input("Ingrese la humedad:  "))
probabilidad_lluvia=float(input("Ingrese la probabilidad de lluvia:  " ))
temp_c=float(input("Ingrese la temperatura: "))
if humedad_suelo<35 and probabilidad_lluvia<40:
  print("Regar")
elif hora==11-15 and temp_c>30:
  print("No regar para evitar evaporación")
elif probabilidad_lluvia>=70:
  print("Nunca regar")
else:
  print("El sensor no detecta ningun valor imprimir{ERROR SENSOR}")
# Out:
# Ingrese la humedad:  20
# Ingrese la probabilidad de lluvia:  30
# Ingrese la temperatura: 22
# Regar

# %% [markdown]
# ![1f667b64-2e6b-465a-ac17-5ac0d1465024.jpg](data:image/jpeg;base64,...)

# %%
#Programa de un sistema de tarifación de energía
kilobatios=float(input("Ingrese la cantidad de kilobatios consumidos (kwh): "))
estrato=int(input("Ingrese el estrato (0-6): "))
dia_semana= input("¿Es día de semana? (si/no): ")
festivo = input("¿Es festivo? (si/no): ")
if kilobatios<0 or estrato<0 or estrato>6:
  print("ERROR: Debes programar una visita al predio. ")
else:
  base= (kilobatios*620)
if estrato == 0 or estrato == 1 or estrato == 2:
  descuento = base*0.20
  base_con_descuento = base - descuento
  recargo = (kilobatios - 1000) * 800
  total = base_con_descuento + recargo
  print("Total a pagar: $", total, "(incluye recargo por exceso)")
else:
  base_con_descuento = base
  total= (base_con_descuento)
  print("Total a pagar, Total")
# Out:
# Ingrese la cantidad de kilobatios consumidos (kwh): 1.8
# Ingrese el estrato (0-6): 2
# ¿Es día de semana? (si/no): si
# ¿Es festivo? (si/no): no
# Total a pagar: $ -797667.2 (incluye recargo por exceso)

# %% [markdown]
# ![8c5b18bc-28eb-4360-bf87-170b0b1ba801.jpg](data:image/jpeg;base64,...)
